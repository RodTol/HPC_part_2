# %%
import tabulate
import pandas as pd
import numpy as np

# %%
files = ['times1.dat', 'times2.dat', 'times4.dat', 'times8.dat']

# %%
lines = []
data_frames = []
n_line = 0
for index in range(len(files)):
	with open(files[index]) as file:	
		for line in file.readlines():
			lines += [line.split()]
			n_line+=1

	for i in range(len(lines[0])):
		lines[0][i] = lines[0][i].replace(",","")
	lines[0].insert(0,"Compilation")

	for line in lines[1:]:
		line[1:] = (np.array(line[1:])).astype(np.double) 

	#lines =  lines[0:len(lines)-3]
	df = pd.DataFrame(lines[1:])
	df.columns = lines[0]
	data_frames.append(df)
	lines = []

for i in data_frames:
	display(i)
# Out:
#    Compilation        N  n_proc_tot  comm_total  compute_total
# 0          MPI   1000.0        32.0    0.096898       0.109696
# 1     OpenBLAS   1000.0        32.0    0.010963       0.009615
# 2       cuBLAS   1000.0        32.0    2.078236       0.139624
# 3          MPI   5000.0        32.0    0.345981      13.293742
# 4     OpenBLAS   5000.0        32.0    0.167434       0.480081
# 5       cuBLAS   5000.0        32.0    2.129919       0.066219
# 6          MPI  10000.0        32.0    3.018927     112.421721
# 7     OpenBLAS  10000.0        32.0    1.332472       3.400174
# 8       cuBLAS  10000.0        32.0    2.674562       0.057627
# 9          MPI  15000.0        32.0   11.188614     498.364162
# 10    OpenBLAS  15000.0        32.0    1.888626      11.407464
# 11      cuBLAS  15000.0        32.0    3.931169       0.186469
# 12         MPI  20000.0        32.0   44.126541    1100.084288
# 13    OpenBLAS  20000.0        32.0    2.785680      26.073153
# 14      cuBLAS  20000.0        32.0    5.517123       0.589171
# 15         MPI  25000.0        32.0   27.783137    2303.556687
# 16    OpenBLAS  25000.0        32.0    3.547980      50.816127
# 17      cuBLAS  25000.0        32.0    7.045122       1.242960
# 18         MPI  30000.0        32.0   47.328050    4704.344016
# 19    OpenBLAS  30000.0        32.0    5.679996      87.001917
# 20      cuBLAS  30000.0        32.0    9.355953       1.882099
#    Compilation        N  n_proc_tot  comm_total  compute_total
# 0          MPI   1000.0        64.0    0.122118       0.035366
# 1     OpenBLAS   1000.0        64.0    0.031048       0.006280
# 2       cuBLAS   1000.0        64.0    2.084678       0.162821
# 3          MPI   5000.0        64.0    0.371349       6.451612
# 4     OpenBLAS   5000.0        64.0    0.398094       0.259901
# 5       cuBLAS   5000.0        64.0    2.090775       0.111764
# 6          MPI  10000.0        64.0    2.006719      57.352202
# 7     OpenBLAS  10000.0        64.0    0.594567       1.800960
# 8       cuBLAS  10000.0        64.0    2.638948       0.091841
# 9          MPI  15000.0        64.0    5.680913     245.832777
# 10    OpenBLAS  15000.0        64.0    3.647410       5.826589
# 11      cuBLAS  15000.0        64.0    3.985760       0.132639
# 12         MPI  20000.0        64.0   12.007397     574.105197
# 13    OpenBLAS  20000.0        64.0    5.074608      13.230264
# 14      cuBLAS  20000.0        64.0    5.519502       0.230497
# 15         MPI  25000.0        64.0   37.116704    1149.172217
# 16    OpenBLAS  25000.0        64.0    5.168500      26.235155
# 17      cuBLAS  25000.0        64.0    7.627851       0.584811
# 18         MPI  30000.0        64.0  109.785474    2357.785534
# 19    OpenBLAS  30000.0        64.0    9.600244      44.478492
# 20      cuBLAS  30000.0        64.0    9.731658       1.413002
#    Compilation        N  n_proc_tot  comm_total  compute_total
# 0     OpenBLAS   5000.0       128.0    0.079580       0.158288
# 1       cuBLAS   5000.0        16.0    0.239185       0.004990
# 2     OpenBLAS  10000.0       128.0    0.439106       1.091659
# 3       cuBLAS  10000.0        16.0    0.474143       0.023021
# 4     OpenBLAS  15000.0       128.0    1.296232       3.256682
# 5       cuBLAS  15000.0        16.0    0.749914       0.072662
# 6     OpenBLAS  20000.0       128.0    1.937036       7.260679
# 7       cuBLAS  20000.0        16.0    1.208782       0.158604
# 8     OpenBLAS  30000.0       128.0    4.759953      23.498852
# 9       cuBLAS  30000.0        16.0    2.477200       0.545544
# 10    OpenBLAS  35000.0       128.0    6.241665      36.065541
# 11      cuBLAS  35000.0        16.0    3.325655       0.778728
# 12    OpenBLAS  40000.0       128.0    7.985784      53.566651
# 13      cuBLAS  40000.0        16.0    4.113143       1.090812
# 14    OpenBLAS  45000.0       128.0   10.667763      76.275735
# 15      cuBLAS  45000.0        16.0    5.233743       1.540723
# 16    OpenBLAS  50000.0       128.0   12.983012     105.833449
# 17      cuBLAS  50000.0        16.0    6.368611       2.180104
# 18         MPI   5000.0       128.0    0.361394       3.928218
# 19         MPI  10000.0       128.0    1.469902      30.144040
# 20         MPI  15000.0       128.0   19.573512     127.277647
# 21         MPI  20000.0       128.0   11.777824     286.566441
#    Compilation        N  n_proc_tot  comm_total  compute_total
# 0          MPI   5000.0       256.0    0.350222       1.799336
# 1     OpenBLAS   5000.0       256.0    0.107617       0.101318
# 2       cuBLAS   5000.0        32.0    0.250935       0.036464
# 3          MPI  10000.0       256.0    1.136382      15.732309
# 4     OpenBLAS  10000.0       256.0    0.473476       0.647191
# 5       cuBLAS  10000.0        32.0    0.494985       0.016457
# 6          MPI  15000.0       256.0    4.383173      61.277440
# 7     OpenBLAS  15000.0       256.0    2.039367       1.893929
# 8       cuBLAS  15000.0        32.0    0.829914       0.041377
# 9          MPI  20000.0       256.0    8.382808     142.836418
# 10    OpenBLAS  20000.0       256.0    2.811297       4.456696
# 11      cuBLAS  20000.0        32.0    1.214859       0.087643
# 12         MPI  30000.0       256.0   36.420954     584.231326
# 13    OpenBLAS  30000.0       256.0    3.722980      14.062402
# 14      cuBLAS  30000.0        32.0    2.520758       0.287111
# 15         MPI  35000.0       256.0   41.401570    1228.409916
# 16    OpenBLAS  35000.0       256.0    4.981315      21.019952
# 17      cuBLAS  35000.0        32.0    3.186431       0.471890
# 18         MPI  40000.0       256.0   58.208721    2219.023229
# 19    OpenBLAS  40000.0       256.0    7.716962      30.550246
# 20      cuBLAS  40000.0        32.0    4.320834       0.630800
# 21         MPI  45000.0       256.0  116.357343    3702.961726
# 22    OpenBLAS  45000.0       256.0   11.395050      40.237822
# 23      cuBLAS  45000.0        32.0    5.220249       0.902232

# %%
import matplotlib.pyplot as plt

def calc_comm_time(df):
    comm_time_mpi = []
    comm_time_blas = []
    comm_time_cublas = []
    for i in range(int(df["comm_total"].shape[0])):
        if df["Compilation"][i]=="MPI":
            comm_time_mpi.append(df["comm_total"][i])
        elif df["Compilation"][i]=="OpenBLAS":
            comm_time_blas.append(df["comm_total"][i])
        elif df["Compilation"][i]=="cuBLAS":
            comm_time_cublas.append(df["comm_total"][i])

    comm_time = [comm_time_mpi, comm_time_blas, comm_time_cublas]
    return comm_time

def calc_compute_time(df):
    compute_time_mpi = []
    compute_time_blas = []
    compute_time_cublas = []
    for i in range(int(df["compute_total"].shape[0])):
        if df["Compilation"][i]=="MPI":
            compute_time_mpi.append(df["compute_total"][i])
        elif df["Compilation"][i]=="OpenBLAS":
            compute_time_blas.append(df["compute_total"][i])
        elif df["Compilation"][i]=="cuBLAS":
            compute_time_cublas.append(df["compute_total"][i])

    compute_time = [compute_time_mpi, compute_time_blas, compute_time_cublas]
    return compute_time

def calc_name(df):
    name = []
    for i in range(int(df["N"].shape[0])):
        name.append(df["N"][i])
    name = list(dict.fromkeys(name))
    return name

# %%
calc_comm_time(data_frames[2])[1]
# Out:
# [0.009503263,
#  0.079580038,
#  0.439105957,
#  1.296231715,
#  1.937036288,
#  4.759952851,
#  6.241664561,
#  7.985784415,
#  10.667763021,
#  12.983011986]

# %%
def plot(df):
    comm_time = calc_comm_time(df)
    compute_time = calc_compute_time(df)
    name = calc_name(df)
    X = np.arange(len(comm_time[1]))

    print(calc_comm_time(df))
    print(calc_compute_time(df))
    print(calc_name(df))

    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    #ax.bar(X + 0.00, comm_time[0], color = 'b', width = 0.25)
    #ax.bar(X + 0.00, compute_time[0], bottom=comm_time[0], color = 'c', width = 0.25)
    ax.bar(X + 0.25, comm_time[1], color = 'g', width = 0.25)
    ax.bar(X + 0.25, compute_time[1], bottom=comm_time[1], color = 'LightGreen', width = 0.25)
    ax.bar(X + 0.50, comm_time[2], color = 'r', width = 0.25)
    ax.bar(X + 0.50, compute_time[2], bottom=comm_time[2], color = 'm', width = 0.25)

    ticks = ['N = ' +str(size) for size in name]
    ax.set_xticks(X+0.25, (ticks))
    ax.legend(labels=['openBLAS comunication', 'openBLAS computation', 'cuBLAS communication',  'cuBLAS computation'])

    plt.show()

# %%
for i in data_frames:
    #print("Data frame #" + str(i))
    plot(i)
# Out:
# [5000.0, 10000.0, 15000.0, 20000.0, 30000.0, 35000.0, 40000.0, 45000.0]

# %%
def scalability(vector_df):
    comm_time_accros = []
    compute_time_accros = []
    name_accros = []    
    
    comm_time_1 = []
    comm_time_2 = []
    comm_time_3 = []
    compute_time_1 = []
    compute_time_2 = []
    compute_time_3 = []
    
    
    for i in vector_df:
        comm_time = calc_comm_time(i)
        compute_time = calc_compute_time(i)
        name = calc_name(i)
        for j in range(len(name)):
            if(name[j]==45000):
                #comm_time_1.append(comm_time[0][j])
                comm_time_2.append(comm_time[1][j])
                comm_time_3.append(comm_time[2][j])
            
                #compute_time_1.append(compute_time[0][j])
                compute_time_2.append(compute_time[1][j])
                compute_time_3.append(compute_time[2][j])

    comm_time_accros = [comm_time_2, comm_time_3]
    compute_time_accros = [compute_time_2, compute_time_3]
    print(comm_time_accros)
    print(compute_time_accros)

    #X = np.arange(len(comm_time_accros[0]))
    X = np.array([1,2,4,8])
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    #ax.bar(X + 0.00, comm_time_accros[0], color = 'b', width = 0.25)
    #ax.bar(X + 0.00, compute_time_accros[0], bottom=comm_time_accros[0], color = 'c', width = 0.25)
    
    ax.bar(X + 0.25, comm_time_accros[0], color = 'g', width = 0.25)
    ax.bar(X + 0.25, compute_time_accros[0], bottom=comm_time_accros[1], color = 'LightGreen', width = 0.25)

    ax.bar(X + 0.50, comm_time_accros[1], color = 'r', width = 0.25)
    ax.bar(X + 0.50, compute_time_accros[1], bottom=comm_time_accros[2], color = 'm', width = 0.25)

    ax.set_ylabel('Times[s]')
    ax.set_xticks(X+0.25, ('N = 1', 'N = 2', 'N = 4', 'N = 8'))
    ax.legend(labels=['openBLAS communication', 'openBLAS computation', 'cuBLAS communication',  'cuBLAS computation'])
    ax.grid(linestyle = '--', axis = 'y')
    plt.show()

scalability(data_frames[1:])
# Out:
# [[10.667763021, 11.395049979], [5.233743164063, 5.220248535156]]
# [[76.275735209, 40.237821827], [1.540723022461, 0.902232299805]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 52
#      49     ax.grid(linestyle = '--', axis = 'y')
#      50     plt.show()
# ---> 52 scalability(data_frames[1:])
#
# Cell In[60], line 40, in scalability(vector_df)
#      36 ax = fig.add_axes([0,0,1,1])
#      37 #ax.bar(X + 0.00, comm_time_accros[0], color = 'b', width = 0.25)
#      38 #ax.bar(X + 0.00, compute_time_accros[0], bottom=comm_time_accros[0], color = 'c', width = 0.25)
# ---> 40 ax.bar(X + 0.25, comm_time_accros[0], color = 'g', width = 0.25)
#      41 ax.bar(X + 0.25, compute_time_accros[0], bottom=comm_time_accros[1], color = 'LightGreen', width = 0.25)
#      43 ax.bar(X + 0.50, comm_time_accros[1], color = 'r', width = 0.25)
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py:2417, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2414     if yerr is not None:
#    2415         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2417 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2418     # Make args iterable too.
#    2419     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2421 # Now that units have been converted, set the tick locations.
#    2422 if orientation == 'vertical':
#
# File <__array_function__ internals>:200, in broadcast_arrays(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:540, in broadcast_arrays(subok, *args)
#     533 # nditer is not used here to avoid the limit of 32 arrays.
#     534 # Otherwise, something like the following one-liner would suffice:
#     535 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     536 #                  order='C').itviews
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 540 shape = _broadcast_shape(*args)
#     542 if all(array.shape == shape for array in args):
#     543     # Common case where nothing needs to be broadcasted.
#     544     return args
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:422, in _broadcast_shape(*args)
#     417 """Returns the shape of the arrays that would result from broadcasting the
#     418 supplied arrays against each other.
#     419 """
#     420 # use the old-iterator because np.nditer does not handle size 0 arrays
#     421 # consistently
# --> 422 b = np.broadcast(*args[:32])
#     423 # unfortunately, it cannot handle 32 or more arguments directly
#     424 for pos in range(32, len(args), 31):
#     425     # ironically, np.broadcast does not properly handle np.broadcast
#     426     # objects (it treats them as scalars)
#     427     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (4,) and arg 1 with shape (2,).
