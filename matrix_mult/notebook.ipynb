# %%
import tabulate
import pandas as pd
import numpy as np

# %%
files = ['times1.dat', 'times2.dat', 'times4.dat', 'times8.dat']

# %%
lines = []
data_frames = []
n_line = 0
for index in range(len(files)):
	with open(files[index]) as file:	
		for line in file.readlines():
			lines += [line.split()]
			n_line+=1

	for i in range(len(lines[0])):
		lines[0][i] = lines[0][i].replace(",","")
	lines[0].insert(0,"Compilation")

	for line in lines[1:]:
		line[1:] = (np.array(line[1:])).astype(np.double) 

	#lines =  lines[0:len(lines)-3]
	df = pd.DataFrame(lines[1:])
	df.columns = lines[0]
	data_frames.append(df)
	lines = []

for i in data_frames:
	display(i)
# Out:
#    Compilation        N  n_proc_tot  comm_total  compute_total
# 0          MPI   1000.0        32.0    0.096898       0.109696
# 1     OpenBLAS   1000.0        32.0    0.010963       0.009615
# 2       cuBLAS   1000.0        32.0    2.078236       0.139624
# 3          MPI   5000.0        32.0    0.345981      13.293742
# 4     OpenBLAS   5000.0        32.0    0.167434       0.480081
# 5       cuBLAS   5000.0        32.0    2.129919       0.066219
# 6          MPI  10000.0        32.0    3.018927     112.421721
# 7     OpenBLAS  10000.0        32.0    1.332472       3.400174
# 8       cuBLAS  10000.0        32.0    2.674562       0.057627
# 9          MPI  15000.0        32.0   11.188614     498.364162
# 10    OpenBLAS  15000.0        32.0    1.888626      11.407464
# 11      cuBLAS  15000.0        32.0    3.931169       0.186469
# 12         MPI  20000.0        32.0   44.126541    1100.084288
# 13    OpenBLAS  20000.0        32.0    2.785680      26.073153
# 14      cuBLAS  20000.0        32.0    5.517123       0.589171
# 15         MPI  25000.0        32.0   27.783137    2303.556687
# 16    OpenBLAS  25000.0        32.0    3.547980      50.816127
# 17      cuBLAS  25000.0        32.0    7.045122       1.242960
# 18         MPI  30000.0        32.0   47.328050    4704.344016
# 19    OpenBLAS  30000.0        32.0    5.679996      87.001917
# 20      cuBLAS  30000.0        32.0    9.355953       1.882099
#    Compilation        N  n_proc_tot  comm_total  compute_total
# 0          MPI   1000.0        64.0    0.122118       0.035366
# 1     OpenBLAS   1000.0        64.0    0.031048       0.006280
# 2       cuBLAS   1000.0        64.0    2.084678       0.162821
# 3          MPI   5000.0        64.0    0.371349       6.451612
# 4     OpenBLAS   5000.0        64.0    0.398094       0.259901
# 5       cuBLAS   5000.0        64.0    2.090775       0.111764
# 6          MPI  10000.0        64.0    2.006719      57.352202
# 7     OpenBLAS  10000.0        64.0    0.594567       1.800960
# 8       cuBLAS  10000.0        64.0    2.638948       0.091841
# 9          MPI  15000.0        64.0    5.680913     245.832777
# 10    OpenBLAS  15000.0        64.0    3.647410       5.826589
# 11      cuBLAS  15000.0        64.0    3.985760       0.132639
# 12         MPI  20000.0        64.0   12.007397     574.105197
# 13    OpenBLAS  20000.0        64.0    5.074608      13.230264
# 14      cuBLAS  20000.0        64.0    5.519502       0.230497
# 15         MPI  25000.0        64.0   37.116704    1149.172217
# 16    OpenBLAS  25000.0        64.0    5.168500      26.235155
# 17      cuBLAS  25000.0        64.0    7.627851       0.584811
# 18         MPI  30000.0        64.0  109.785474    2357.785534
# 19    OpenBLAS  30000.0        64.0    9.600244      44.478492
# 20      cuBLAS  30000.0        64.0    9.731658       1.413002
#    Compilation        N  n_proc_tot  comm_total  compute_total
# 0          MPI   1000.0       128.0    0.035144       0.014334
# 1     OpenBLAS   1000.0       128.0    0.044941       0.001931
# 2       cuBLAS   1000.0       128.0    2.377961       0.262477
# 3          MPI   5000.0       128.0    0.628435       3.952832
# 4     OpenBLAS   5000.0       128.0    0.572723       0.155119
# 5       cuBLAS   5000.0       128.0    2.393394       0.343114
# 6          MPI  10000.0       128.0    1.805349      29.285431
# 7     OpenBLAS  10000.0       128.0    1.149686       1.068337
# 8       cuBLAS  10000.0       128.0    3.240166       0.085118
# 9          MPI  15000.0       128.0    4.577311     126.697823
# 10    OpenBLAS  15000.0       128.0    1.587494       3.268480
# 11      cuBLAS  15000.0       128.0    3.674783       0.270164
# 12         MPI  20000.0       128.0   10.217927     281.686031
# 13    OpenBLAS  20000.0       128.0    2.692506       7.269449
# 14      cuBLAS  20000.0       128.0    4.571021       0.474459
# 15         MPI  25000.0       128.0   28.044681     600.426054
# 16    OpenBLAS  25000.0       128.0   16.069114      14.031841
# 17      cuBLAS  25000.0       128.0    8.630824       0.384898
# 18         MPI  30000.0       128.0   47.858616    1197.904703
# 19    OpenBLAS  30000.0       128.0   19.559922      23.577413
# 20      cuBLAS  30000.0       128.0   11.317408       0.365182
# 21        None      NaN         NaN         NaN            NaN
#    Compilation        N  n_proc_tot  comm_total  compute_total
# 0          MPI   1000.0       256.0    0.026907       0.007165
# 1     OpenBLAS   1000.0       256.0    0.025923       0.001869
# 2       cuBLAS   1000.0        32.0    1.175586       0.078488
# 3          MPI   5000.0       256.0    0.350222       1.799336
# 4     OpenBLAS   5000.0       256.0    0.107617       0.101318
# 5       cuBLAS   5000.0        32.0    0.250935       0.036464
# 6          MPI  10000.0       256.0    1.136382      15.732309
# 7     OpenBLAS  10000.0       256.0    0.473476       0.647191
# 8       cuBLAS  10000.0        32.0    0.494985       0.016457
# 9          MPI  15000.0       256.0    4.383173      61.277440
# 10    OpenBLAS  15000.0       256.0    2.039367       1.893929
# 11      cuBLAS  15000.0        32.0    0.829914       0.041377
# 12         MPI  20000.0       256.0    8.382808     142.836418
# 13    OpenBLAS  20000.0       256.0    2.811297       4.456696
# 14      cuBLAS  20000.0        32.0    1.214859       0.087643
# 15         MPI  30000.0       256.0   36.420954     584.231326
# 16    OpenBLAS  30000.0       256.0    3.722980      14.062402
# 17      cuBLAS  30000.0        32.0    2.520758       0.287111
# 18         MPI  35000.0       256.0   41.401570    1228.409916
# 19    OpenBLAS  35000.0       256.0    4.981315      21.019952
# 20      cuBLAS  35000.0        32.0    3.186431       0.471890
# 21         MPI  40000.0       256.0   58.208721    2219.023229
# 22    OpenBLAS  40000.0       256.0    7.716962      30.550246
# 23      cuBLAS  40000.0        32.0    4.320834       0.630800
# 24         MPI  45000.0       256.0  116.357343    3702.961726
# 25    OpenBLAS  45000.0       256.0   11.395050      40.237822
# 26      cuBLAS  45000.0        32.0    5.220249       0.902232

# %%
import matplotlib.pyplot as plt

def calc_comm_time(df):
    comm_time_1 = []
    comm_time_2 = []
    comm_time_3 = []
    for i in range(int(df["comm_total"].shape[0]/3)):
        comm_time_1.append(df["comm_total"][i*3])
        comm_time_2.append(df["comm_total"][i*3+1])
        comm_time_3.append(df["comm_total"][i*3+2])

    comm_time = [comm_time_1, comm_time_2, comm_time_3]
    return comm_time

def calc_compute_time(df):
    compute_time_1 = []
    compute_time_2 = []
    compute_time_3 = []
    for i in range(int(df["compute_total"].shape[0]/3)):
        compute_time_1.append(df["compute_total"][i*3])
        compute_time_2.append(df["compute_total"][i*3+1])
        compute_time_3.append(df["compute_total"][i*3+2])

    compute_time = [compute_time_1, compute_time_2, compute_time_3]
    return compute_time

def calc_name(df):
    name = []
    for i in range(int(df["N"].shape[0]/3)):
        name.append(df["N"][i*3])
    return name

# %%
def plot(df):
    comm_time = calc_comm_time(df)
    compute_time = calc_compute_time(df)
    name = calc_name(df)
    X = np.arange(len(comm_time[0]))

    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    #ax.bar(X + 0.00, comm_time[0], color = 'b', width = 0.25)
    #ax.bar(X + 0.00, compute_time[0], bottom=comm_time[0], color = 'c', width = 0.25)
    ax.bar(X + 0.25, comm_time[1], color = 'g', width = 0.25)
    ax.bar(X + 0.25, compute_time[1], bottom=comm_time[1], color = 'LightGreen', width = 0.25)
    ax.bar(X + 0.50, comm_time[2], color = 'r', width = 0.25)
    ax.bar(X + 0.50, compute_time[2], bottom=comm_time[2], color = 'm', width = 0.25)

    ticks = ['N = ' +str(size) for size in name]
    ax.set_xticks(X+0.25, (ticks))
    ax.legend(labels=['openBLAS comunication', 'openBLAS computation', 'cuBLAS communication',  'cuBLAS computation'])

    plt.show()

# %%
for i in data_frames:
    plot(i)

# %%
def scalability(vector_df):
    comm_time_accros = []
    compute_time_accros = []
    name_accros = []    
    
    comm_time_1 = []
    comm_time_2 = []
    comm_time_3 = []
    compute_time_1 = []
    compute_time_2 = []
    compute_time_3 = []
    
    
    for i in vector_df:
        comm_time = calc_comm_time(i)
        compute_time = calc_compute_time(i)
        name = calc_name(i)
        for j in range(len(name)):
            if(name[j]==30000):
                comm_time_1.append(comm_time[0][j])
                comm_time_2.append(comm_time[1][j])
                comm_time_3.append(comm_time[2][j])
            
                compute_time_1.append(compute_time[0][j])
                compute_time_2.append(compute_time[1][j])
                compute_time_3.append(compute_time[2][j])

    comm_time_accros = [comm_time_1,comm_time_2, comm_time_3]
    compute_time_accros = [compute_time_1, compute_time_2, compute_time_3]
    print(comm_time_accros)
    print(compute_time_accros)

    #X = np.arange(len(comm_time_accros[0]))
    X = np.array([1,2,4,8])
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    #ax.bar(X + 0.00, comm_time_accros[0], color = 'b', width = 0.25)
    #ax.bar(X + 0.00, compute_time_accros[0], bottom=comm_time_accros[0], color = 'c', width = 0.25)
    
    ax.bar(X + 0.25, comm_time_accros[1], color = 'g', width = 0.25)
    ax.bar(X + 0.25, compute_time_accros[1], bottom=comm_time_accros[1], color = 'LightGreen', width = 0.25)

    ax.bar(X + 0.50, comm_time_accros[2], color = 'r', width = 0.25)
    ax.bar(X + 0.50, compute_time_accros[2], bottom=comm_time_accros[2], color = 'm', width = 0.25)

    ax.set_ylabel('Times[s]')
    ax.set_xticks(X+0.25, ('N = 1', 'N = 2', 'N = 4', 'N = 8'))
    ax.legend(labels=['openBLAS communication', 'openBLAS computation', 'cuBLAS communication',  'cuBLAS computation'])
    ax.grid(linestyle = '--', axis = 'y')
    plt.show()

scalability(data_frames)
# Out:
# [[47.328049763999, 109.785474127001, 47.858616395999, 36.420954205001], [5.679996252, 9.600244474, 19.559922287, 3.722980023], [9.355953125, 9.731658203125, 11.317408203125, 2.520757568359]]
# [[4704.344015501002, 2357.785533595001, 1197.904702826, 584.231326033], [87.001916696, 44.478492187, 23.577412516, 14.062402093], [1.882098632813, 1.413002441406, 0.365181640625, 0.287110870361]]
